# %% [markdown]
# **1. Generate a List of 100 Integers and Perform Statistical
# Calculations**
#
# **(i) Mean of a List:**
#
# python
#
# CopyEdit
#
# import numpy as np
#
# def calculate_mean(lst):
#
# return np.mean(lst)
#
# int_list = np.random.randint(90, 131, size=100)
#
# mean_value = calculate_mean(int_list)
#
# print("Mean:", mean_value)
#
# **(ii) Median of a List:**
#
# python
#
# CopyEdit
#
# def calculate_median(lst):
#
# return np.median(lst)
#
# median_value = calculate_median(int_list)
#
# print("Median:", median_value)
#
# **(iii) Mode of a List:**
#
# python
#
# CopyEdit
#
# from scipy import stats
#
# def calculate_mode(lst):
#
# mode = stats.mode(lst)
#
# return mode.mode\[0\]
#
# mode_value = calculate_mode(int_list)
#
# print("Mode:", mode_value)
#
# **(iv) Weighted Mean:**
#
# python
#
# CopyEdit
#
# def weighted_mean(values, weights):
#
# return np.average(values, weights=weights)
#
# values = np.random.randint(90, 131, size=100)
#
# weights = np.random.rand(100)
#
# weighted_avg = weighted_mean(values, weights)
#
# print("Weighted Mean:", weighted_avg)
#
# **(v) Geometric Mean:**
#
# python
#
# CopyEdit
#
# def geometric_mean(lst):
#
# return np.exp(np.mean(np.log(lst)))
#
# geometric_avg = geometric_mean(int_list\[int_list \> 0\]) \# Ensure all
# values are positive
#
# print("Geometric Mean:", geometric_avg)
#
# **(vi) Harmonic Mean:**
#
# python
#
# CopyEdit
#
# def harmonic_mean(lst):
#
# return len(lst) / np.sum(1.0 / np.array(lst))
#
# harmonic_avg = harmonic_mean(int_list\[int_list \> 0\]) \# Ensure all
# values are positive
#
# print("Harmonic Mean:", harmonic_avg)
#
# **(vii) Midrange:**
#
# python
#
# CopyEdit
#
# def midrange(lst):
#
# return (np.min(lst) + np.max(lst)) / 2
#
# midrange_value = midrange(int_list)
#
# print("Midrange:", midrange_value)
#
# **(viii) Trimmed Mean:**
#
# python
#
# CopyEdit
#
# from scipy.stats import trim_mean
#
# def trimmed_mean(lst, proportion_to_cut):
#
# return trim_mean(lst, proportion_to_cut)
#
# trimmed_avg = trimmed_mean(int_list, 0.1) \# 10% trimming
#
# print("Trimmed Mean:", trimmed_avg)
#
# **2. Generate a List of 500 Integers and Perform Statistical
# Calculations**
#
# **(i) Frequency & Gaussian Distribution Visualization:**
#
# python
#
# CopyEdit
#
# import seaborn as sns
#
# import matplotlib.pyplot as plt
#
# int_list2 = np.random.randint(200, 301, size=500)
#
# sns.histplot(int_list2, kde=True)
#
# plt.title('Frequency & Gaussian Distribution')
#
# plt.show()
#
# **(ii) Range of a List:**
#
# python
#
# CopyEdit
#
# def calculate_range(lst):
#
# return np.max(lst) - np.min(lst)
#
# range_value = calculate_range(int_list2)
#
# print("Range:", range_value)
#
# **(iii) Variance and Standard Deviation:**
#
# python
#
# CopyEdit
#
# def variance_and_std(lst):
#
# return np.var(lst), np.std(lst)
#
# variance, std_dev = variance_and_std(int_list2)
#
# print("Variance:", variance)
#
# print("Standard Deviation:", std_dev)
#
# **(iv) Interquartile Range (IQR):**
#
# python
#
# CopyEdit
#
# def interquartile_range(lst):
#
# return np.percentile(lst, 75) - np.percentile(lst, 25)
#
# iqr_value = interquartile_range(int_list2)
#
# print("Interquartile Range:", iqr_value)
#
# **(v) Coefficient of Variation:**
#
# python
#
# CopyEdit
#
# def coefficient_of_variation(lst):
#
# return np.std(lst) / np.mean(lst)
#
# cv_value = coefficient_of_variation(int_list2)
#
# print("Coefficient of Variation:", cv_value)
#
# **(vi) Mean Absolute Deviation (MAD):**
#
# python
#
# CopyEdit
#
# def mean_absolute_deviation(lst):
#
# return np.mean(np.abs(lst - np.mean(lst)))
#
# mad_value = mean_absolute_deviation(int_list2)
#
# print("Mean Absolute Deviation:", mad_value)
#
# **(vii) Quartile Deviation:**
#
# python
#
# CopyEdit
#
# def quartile_deviation(lst):
#
# q1 = np.percentile(lst, 25)
#
# q3 = np.percentile(lst, 75)
#
# return (q3 - q1) / 2
#
# qd_value = quartile_deviation(int_list2)
#
# print("Quartile Deviation:", qd_value)
#
# **(viii) Range-Based Coefficient of Dispersion:**
#
# python
#
# CopyEdit
#
# def range_based_dispersion(lst):
#
# return (np.max(lst) - np.min(lst)) / np.mean(lst)
#
# dispersion_value = range_based_dispersion(int_list2)
#
# print("Range-Based Coefficient of Dispersion:", dispersion_value)
#
# **3. Z-Test for Layout Conversion Rate**
#
# python
#
# CopyEdit
#
# from scipy import stats
#
# old_layout = np.array(\[1\] \* 50 + \[0\] \* 950)
#
# new_layout = np.array(\[1\] \* 70 + \[0\] \* 930)
#
# \# Z-test for proportions
#
# p_old = np.mean(old_layout)
#
# p_new = np.mean(new_layout)
#
# n_old = len(old_layout)
#
# n_new = len(new_layout)
#
# z_score = (p_new - p_old) / np.sqrt((p_old \* (1 - p_old) / n_old) +
# (p_new \* (1 - p_new) / n_new))
#
# p_value = 1 - stats.norm.cdf(z_score)
#
# print("Z-Score:", z_score)
#
# print("P-Value:", p_value)
#
# **4. T-Test for Various Scenarios (Before & After)**
#
# **(i) T-Test for Website Layout Clicks**
#
# python
#
# CopyEdit
#
# layout_a\_clicks = \[28, 32, 33, 29, 31, 34, 30, 35, 36, 37\]
#
# layout_b\_clicks = \[40, 41, 38, 42, 39, 44, 43, 41, 45, 47\]
#
# t_stat, p_val = stats.ttest_ind(layout_a\_clicks, layout_b\_clicks)
#
# print("T-Statistic:", t_stat)
#
# print("P-Value:", p_val)
#
# **(ii) T-Test for Drug Effectiveness (Cholesterol Levels)**
#
# python
#
# CopyEdit
#
# existing_drug_levels = \[180, 182, 175, 185, 178, 176, 172, 184, 179,
# 183\]
#
# new_drug_levels = \[170, 172, 165, 168, 175, 173, 170, 178, 172, 176\]
#
# t_stat, p_val = stats.ttest_ind(existing_drug_levels, new_drug_levels)
#
# print("T-Statistic:", t_stat)
#
# print("P-Value:", p_val)
#
# **(iii) T-Test for Pre/Post Intervention Scores**
#
# python
#
# CopyEdit
#
# pre_intervention_scores = \[80, 85, 90, 75, 88, 82, 92, 78, 85, 87\]
#
# post_intervention_scores = \[90, 92, 88, 92, 95, 91, 96, 93, 89, 93\]
#
# t_stat, p_val = stats.ttest_rel(pre_intervention_scores,
# post_intervention_scores)
#
# print("T-Statistic:", t_stat)
#
# print("P-Value:", p_val)
#
# **5. Chi-Square Test for Associations**
#
# **(i) Chi-Square Test for Voter Preferences by Age Group**
#
# python
#
# CopyEdit
#
# from scipy.stats import chi2_contingency
#
# age_groups = np.random.choice(\['18-30', '31-50', '51+'\], size=30)
#
# voter_preferences = np.random.choice(\['Candidate A', 'Candidate B'\],
# size=30)
#
# contingency_table = np.crosstab(age_groups, voter_preferences)
#
# chi2, p_val, dof, expected = chi2_contingency(contingency_table)
#
# print("Chi-Square Statistic:", chi2)
#
# print("P-Value:", p_val)
#
# **(ii) Chi-Square Test for Job Performance Before and After Training**
#
# python
#
# CopyEdit
#
# data = np.array(\[\[50, 30, 20\], \[30, 40, 30\], \[20, 30, 40\]\])
#
# chi2, p_val, dof, expected = chi2_contingency(data)
#
# print("Chi-Square Statistic:", chi2)
#
# print("P-Value:", p_val)
#
# **6. ANOVA Test for Customer Satisfaction Scores**
#
# python
#
# CopyEdit
#
# from scipy.stats import f_oneway
#
# standard_scores = \[80, 85, 90, 78, 88, 82, 92, 78, 85, 87\]
#
# premium_scores = \[90, 92, 88, 92, 95, 91, 96, 93, 89, 93\]
#
# deluxe_scores = \[95, 98, 92, 97, 96, 94, 98, 97, 92, 99\]
#
# f_stat, p_val = f_oneway(standard_scores, premium_scores, deluxe_scores)
#
# print("F-Statistic:", f_stat)
#
# print("P-Value:", p_val)
#
# **4. Simulate the Rolling of a Fair Six-Sided Die and Calculate the
# Expected Value and Variance of the Outcomes**
#
# python
#
# CopyEdit
#
# import numpy as np
#
# \# Simulate rolling a six-sided die 1000 times
#
# rolls = np.random.choice(\[1, 2, 3, 4, 5, 6\], size=1000)
#
# \# Expected value (mean)
#
# expected_value = np.mean(rolls)
#
# \# Variance
#
# variance = np.var(rolls)
#
# expected_value, variance
#
# **5. Generate Random Samples from a Given Probability Distribution
# (e.g., Binomial, Poisson) and Calculate Their Mean and Variance**
#
# **(i) Binomial Distribution**
#
# python
#
# CopyEdit
#
# \# Generate 1000 random samples from a binomial distribution
#
# binomial_samples = np.random.binomial(n=10, p=0.5, size=1000)
#
# \# Mean and Variance
#
# binomial_mean = np.mean(binomial_samples)
#
# binomial_variance = np.var(binomial_samples)
#
# binomial_mean, binomial_variance
#
# **(ii) Poisson Distribution**
#
# python
#
# CopyEdit
#
# \# Generate 1000 random samples from a Poisson distribution
#
# poisson_samples = np.random.poisson(lam=3, size=1000)
#
# \# Mean and Variance
#
# poisson_mean = np.mean(poisson_samples)
#
# poisson_variance = np.var(poisson_samples)
#
# poisson_mean, poisson_variance
#
# **6. Generate Random Numbers from a Gaussian (Normal) Distribution and
# Compute the Mean, Variance, and Standard Deviation of the Samples**
#
# python
#
# CopyEdit
#
# \# Generate 1000 random samples from a normal distribution
#
# normal_samples = np.random.normal(loc=0, scale=1, size=1000)
#
# \# Mean, Variance, and Standard Deviation
#
# normal_mean = np.mean(normal_samples)
#
# normal_variance = np.var(normal_samples)
#
# normal_std_dev = np.std(normal_samples)
#
# normal_mean, normal_variance, normal_std_dev
#
# **7. Calculate the Probability Density Function (PDF) of a Continuous
# Random Variable for a Given Normal Distribution**
#
# python
#
# CopyEdit
#
# import scipy.stats as stats
#
# \# Calculate the PDF for a normal distribution with mean=0 and std=1
#
# x = np.linspace(-5, 5, 100)
#
# pdf_values = stats.norm.pdf(x, loc=0, scale=1)
#
# \# Plot the PDF
#
# import matplotlib.pyplot as plt
#
# plt.plot(x, pdf_values)
#
# plt.title('Normal Distribution PDF')
#
# plt.xlabel('x')
#
# plt.ylabel('PDF')
#
# plt.show()
#
# **8. Calculate the Cumulative Distribution Function (CDF) of Exponential
# Distribution**
#
# python
#
# CopyEdit
#
# \# Calculate the CDF for an exponential distribution with rate=1
#
# x = np.linspace(0, 10, 100)
#
# cdf_values = stats.expon.cdf(x, scale=1)
#
# \# Plot the CDF
#
# plt.plot(x, cdf_values)
#
# plt.title('Exponential Distribution CDF')
#
# plt.xlabel('x')
#
# plt.ylabel('CDF')
#
# plt.show()
#
# **9. Calculate the Probability Mass Function (PMF) of Poisson
# Distribution**
#
# python
#
# CopyEdit
#
# \# Calculate the PMF for a Poisson distribution with lambda=3
#
# k = np.arange(0, 10)
#
# pmf_values = stats.poisson.pmf(k, mu=3)
#
# \# Plot the PMF
#
# plt.bar(k, pmf_values)
#
# plt.title('Poisson Distribution PMF')
#
# plt.xlabel('k')
#
# plt.ylabel('PMF')
#
# plt.show()
#
# **10. Skewness of total_bill and tip Columns in the tips Dataset**
#
# python
#
# CopyEdit
#
# import seaborn as sns
#
# \# Load the tips dataset
#
# tips = sns.load_dataset('tips')
#
# \# Skewness of total_bill and tip columns
#
# total_bill_skew = tips\['total_bill'\].skew()
#
# tip_skew = tips\['tip'\].skew()
#
# total_bill_skew, tip_skew
#
# **11. Determine Whether the Columns Exhibit Positive Skewness, Negative
# Skewness, or Symmetry**
#
# python
#
# CopyEdit
#
# def skewness_type(skew):
#
# if skew \> 0:
#
# return 'Positive Skew'
#
# elif skew \< 0:
#
# return 'Negative Skew'
#
# else:
#
# return 'Symmetric'
#
# total_bill_skew_type = skewness_type(total_bill_skew)
#
# tip_skew_type = skewness_type(tip_skew)
#
# total_bill_skew_type, tip_skew_type
#
# **12. Covariance Between total_bill and tip**
#
# python
#
# CopyEdit
#
# covariance = tips\[\['total_bill', 'tip'\]\].cov().iloc\[0, 1\]
#
# covariance
#
# **13. Pearson Correlation Coefficient Between total_bill and tip**
#
# python
#
# CopyEdit
#
# correlation = tips\[\['total_bill', 'tip'\]\].corr().iloc\[0, 1\]
#
# correlation
#
# **14. Scatter Plot of Correlation Between Two Columns**
#
# python
#
# CopyEdit
#
# sns.scatterplot(data=tips, x='total_bill', y='tip')
#
# plt.title('Scatter Plot of Total Bill vs Tip')
#
# plt.show()
#
# **15. Z-Test for Website Layouts (Old vs. New Layout)**
#
# python
#
# CopyEdit
#
# from statsmodels.stats.weightstats import ztest
#
# old_layout = np.array(\[1\] \* 50 + \[0\] \* 950)
#
# new_layout = np.array(\[1\] \* 70 + \[0\] \* 930)
#
# z_stat, p_value = ztest(old_layout, new_layout)
#
# z_stat, p_value
#
# **16. Z-Test for Exam Scores Before and After the Program**
#
# python
#
# CopyEdit
#
# before_program = np.array(\[75, 80, 85, 70, 90, 78, 92, 88, 82, 87\])
#
# after_program = np.array(\[80, 85, 90, 80, 92, 80, 95, 90, 85, 88\])
#
# z_stat, p_value = ztest(before_program, after_program)
#
# z_stat, p_value
#
# **17. Z-Test for Blood Pressure Before and After Drug**
#
# python
#
# CopyEdit
#
# before_drug = np.array(\[145, 150, 140, 135, 155, 160, 152, 148, 130,
# 138\])
#
# after_drug = np.array(\[130, 140, 132, 128, 145, 148, 138, 136, 125,
# 130\])
#
# z_stat, p_value = ztest(before_drug, after_drug)
#
# z_stat, p_value
#
# **18. Z-Test for Customer Service Response Time**
#
# python
#
# CopyEdit
#
# response_times = np.array(\[4.3, 3.8, 5.1, 4.9, 4.7, 4.2, 5.2, 4.5, 4.6,
# 4.4\])
#
# z_stat, p_value = ztest(response_times, value=5)
#
# z_stat, p_value
#
# **19. A/B Test for Website Layout Click-Through Rates**
#
# python
#
# CopyEdit
#
# layout_a\_clicks = \[28, 32, 33, 29, 31, 34, 30, 35, 36, 37\]
#
# layout_b\_clicks = \[40, 41, 38, 42, 39, 44, 43, 41, 45, 47\]
#
# from scipy import stats
#
# t_stat, p_value = stats.ttest_ind(layout_a\_clicks, layout_b\_clicks)
#
# t_stat, p_value
#
# **20. T-Test for Cholesterol Levels of Two Drugs**
#
# python
#
# CopyEdit
#
# existing_drug_levels = \[180, 182, 175, 185, 178, 176, 172, 184, 179,
# 183\]
#
# new_drug_levels = \[170, 172, 165, 168, 175, 173, 170, 178, 172, 176\]
#
# t_stat, p_value = stats.ttest_ind(existing_drug_levels, new_drug_levels)
#
# t_stat, p_value
#
# **21. T-Test for Pre- and Post-Intervention Test Scores**
#
# python
#
# CopyEdit
#
# pre_intervention_scores = \[80, 85, 90, 75, 88, 82, 92, 78, 85, 87\]
#
# post_intervention_scores = \[90, 92, 88, 92, 95, 91, 96, 93, 89, 93\]
#
# t_stat, p_value = stats.ttest_rel(pre_intervention_scores,
# post_intervention_scores)
#
# t_stat, p_value
#
# **22. T-Test for Gender-Based Salary Gap**
#
# python
#
# CopyEdit
#
# male_salaries = np.random.normal(loc=50000, scale=10000, size=20)
#
# female_salaries = np.random.normal(loc=55000, scale=9000, size=20)
#
# t_stat, p_value = stats.ttest_ind(male_salaries, female_salaries)
#
# t_stat, p_value
#
# **23. T-Test for Product Version Quality Scores**
#
# python
#
# CopyEdit
#
# version1_scores = \[85, 88, 82, 89, 87, 84, 90, 88, 85, 86, 91, 83, 87,
# 84, 89, 86, 84, 88, 85, 86, 89, 90, 87, 88, 85\]
#
# version2_scores = \[80, 78, 83, 81, 79, 82, 76, 80, 78, 81, 77, 82, 80,
# 79, 82, 79, 80, 81, 79, 82, 79, 78, 80, 81, 82\]
#
# t_stat, p_value = stats.ttest_ind(version1_scores, version2_scores)
#
# t_stat, p_value
#
# **24. T-Test for Customer Satisfaction Between Branches**
#
# python
#
# CopyEdit
#
# branch_a\_scores = \[4, 5, 3, 4, 5, 4, 5, 3, 4, 4, 5, 4, 4, 3, 4, 5, 5,
# 4, 3, 4, 5, 4, 3, 5, 4, 4, 5, 3, 4, 5, 4\]
#
# branch_b\_scores = \[3, 4, 2, 3, 4, 3, 4, 2, 3, 3, 4, 3, 3, 2, 3, 4, 4,
# 3, 2, 3, 4, 3, 2, 4, 3, 3, 4, 2, 3, 4, 3\]
#
# t_stat, p_value = stats.ttest_ind(branch_a\_scores, branch_b\_scores)
#
# t_stat, p_value
#
# **25. Chi-Square Test for Age Groups and Voter Preferences**
#
# python
#
# CopyEdit
#
# from scipy.stats import chi2_contingency
#
# \# Generate sample data
#
# age_groups = np.random.choice(\['18
#
# 4o mini
#
# Top of Form
